# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sktime.utils.plotting import plot_series

# %% [markdown]
# ## Plot daily data
# Retrieved from https://finance.yahoo.com/quote/%5ESTOXX50E/

# %%
daily_df = pd.read_csv("eurostocks/yahoo_daily.csv")

# %%
daily_df.index = pd.to_datetime(daily_df["Date"])

# %%
daily_df
# Out:
#                   Date         Open         High          Low        Close  \
# Date
# 2007-03-30  2007-03-30  4177.669922  4207.759766  4160.350098  4181.029785
# 2007-04-02  2007-04-02  4177.310059  4191.759766  4163.770020  4189.549805
# 2007-04-03  2007-04-03  4199.540039  4248.069824  4199.540039  4246.299805
# 2007-04-04  2007-04-04  4252.709961  4261.830078  4242.049805  4261.830078
# 2007-04-05  2007-04-05  4259.979980  4274.169922  4253.790039  4271.540039
# ...                ...          ...          ...          ...          ...
# 2023-05-12  2023-05-12  4304.069824  4344.319824  4304.069824  4317.879883
# 2023-05-15  2023-05-15  4315.850098  4338.140137  4302.759766  4316.410156
# 2023-05-16  2023-05-16  4313.120117  4328.779785  4298.310059  4315.509766
# 2023-05-17  2023-05-17  4313.250000  4332.080078  4293.569824  4323.229980
# 2023-05-19  2023-05-19  4368.240234  4412.879883  4368.240234  4395.299805
#
#               Adj Close      Volume
# Date
# ...

# %%
daily_df.head(10)
# Out:
#                   Date         Open         High          Low        Close  \
# Date
# 2007-03-30  2007-03-30  4177.669922  4207.759766  4160.350098  4181.029785
# 2007-04-02  2007-04-02  4177.310059  4191.759766  4163.770020  4189.549805
# 2007-04-03  2007-04-03  4199.540039  4248.069824  4199.540039  4246.299805
# 2007-04-04  2007-04-04  4252.709961  4261.830078  4242.049805  4261.830078
# 2007-04-05  2007-04-05  4259.979980  4274.169922  4253.790039  4271.540039
# 2007-04-10  2007-04-10  4275.680176  4307.660156  4267.009766  4301.470215
# 2007-04-11  2007-04-11  4298.240234  4326.700195  4284.919922  4293.200195
# 2007-04-12  2007-04-12  4290.109863  4291.100098  4249.299805  4280.020020
# 2007-04-13  2007-04-13  4285.560059  4319.279785  4284.029785  4317.350098
# 2007-04-16  2007-04-16  4333.950195  4380.520020  4333.390137  4379.250000
#
#               Adj Close  Volume
# Date
# 2007-03-30  4181.029785     0.0
# 2007-04-02  4189.549805     0.0
# ...

# %%
plot_series(daily_df["Close"])
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='Close'>)

# %% [markdown]
# ## Plot monthly data
# Retrieved from https://sdw.ecb.europa.eu/quickview.do?SERIES_KEY=143.FM.M.U2.EUR.DS.EI.DJES50I.HSTA

# %%
monthly_df = pd.read_csv("eurostocks/sdw_monthly.csv")

# %%
monthly_df["y"] = monthly_df["s1"]
monthly_df.index = pd.to_datetime(monthly_df["date"])

# %%
monthly_df
# Out:
#                   date  conf       status1         s1          y
# 1986-12-31  1986-12-31   NaN  Normal value   900.8200   900.8200
# 1987-01-31  1987-01-31   NaN  Normal value   877.8641   877.8641
# 1987-02-28  1987-02-28   NaN  Normal value   839.7895   839.7895
# 1987-03-31  1987-03-31   NaN  Normal value   856.6245   856.6245
# 1987-04-30  1987-04-30   NaN  Normal value   888.9836   888.9836
# ...                ...   ...           ...        ...        ...
# 2022-09-30  2022-09-30   NaN  Normal value  3466.1882  3466.1882
# 2022-10-31  2022-10-31   NaN  Normal value  3464.5760  3464.5760
# 2022-11-30  2022-11-30   NaN  Normal value  3839.9562  3839.9562
# 2022-12-31  2022-12-31   NaN  Normal value  3884.6727  3884.6727
# 2023-01-31  2023-01-31   NaN  Normal value  4092.6740  4092.6740
#
# [434 rows x 5 columns]

# %%
plot_series(monthly_df["y"])
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='y'>)

# %%
# to compare with daily (which starts at 2007)
plot_series(monthly_df["y"][monthly_df["date"] > "2007-01-01"])
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='y'>)
