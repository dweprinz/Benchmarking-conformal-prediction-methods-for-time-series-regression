# %%
# data generation and subplots
from utils import SyntheticData, create_subplots, \
train_val_test, split_x_y, compute_aci, optimize_conformal, plot_test_PIs

# %%
import numpy as np

# %%
np.random.seed(500)
n_samples = 3000
syn = SyntheticData(n_samples=n_samples, stationary=False)
X, Y = syn.generate_Y()
syn.plot_Y_series(Y, title="Synthetic Data")
df, T = syn.Y_to_df(X, Y)

# %%
syn.Y_to_csv(Y)
